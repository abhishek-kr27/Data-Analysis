# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishek-kr27/Data-Exploration/blob/main/Google_Trends_DATA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Combine Google Trends with other Time Series Data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tesla= pd.read_csv('TESLA Search Trend vs Price.csv')
df_unemployment= pd.read_csv('UE Benefits Search vs UE Rate 2004-19.csv')
df_Bitcoin= pd.read_csv('Bitcoin Search Trend.csv')
df_Daily_Bitcoin= pd.read_csv('Daily Bitcoin Price.csv')

# %% [markdown]
# **Solution for Tesla**

# %%
df_tesla.head()
# Out:
#         MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0  2010-06-01                3           4.766
# 1  2010-07-01                3           3.988
# 2  2010-08-01                2           3.896
# 3  2010-09-01                2           4.082
# 4  2010-10-01                2           4.368

# %%
df_tesla.shape
# Out:
# (124, 3)

# %%
print(f'Largest value for Tesla in Web Search: {df_tesla.TSLA_WEB_SEARCH.max()}')
print(f'Smallest value for Tesla in Web Search: {df_tesla.TSLA_WEB_SEARCH.min()}')
# Out:
# Largest value for Tesla in Web Search: 31
# Smallest value for Tesla in Web Search: 2

# %%
df_tesla.describe()
# Out:
#        TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# count       124.000000      124.000000
# mean          8.725806       50.962145
# std           5.870332       65.908389
# min           2.000000        3.896000
# 25%           3.750000        7.352500
# 50%           8.000000       44.653000
# 75%          12.000000       58.991999
# max          31.000000      498.320007

# %% [markdown]
# **Solution for Unemployment**

# %%
print(df_unemployment.shape)
df_unemployment.head()
# Out:
# (181, 3)
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                      34     5.7
# 1  2004-02                      33     5.6
# 2  2004-03                      25     5.8
# 3  2004-04                      29     5.6
# 4  2004-05                      23     5.6

# %%
print(f'Largest value for "Unemployemnt Benefits" '
      f'in Web Search {df_unemployment.UE_BENEFITS_WEB_SEARCH.max()}')
# Out:
# Largest value for "Unemployemnt Benefits" in Web Search 100

# %% [markdown]
# **BitCoin**

# %%
print(df_Bitcoin.shape)
df_Bitcoin.head()
# Out:
# (73, 2)
#      MONTH  BTC_NEWS_SEARCH
# 0  2014-09                5
# 1  2014-10                4
# 2  2014-11                4
# 3  2014-12                4
# 4  2015-01                5

# %%
print(f'largest BTC News Search: {df_Bitcoin.BTC_NEWS_SEARCH.max()}')
# Out:
# largest BTC News Search: 100

# %%
print(df_Daily_Bitcoin.shape)
df_Daily_Bitcoin.head()
# Out:
# (2204, 3)
#          DATE       CLOSE      VOLUME
# 0  2014-09-17  457.334015  21056800.0
# 1  2014-09-18  424.440002  34483200.0
# 2  2014-09-19  394.795990  37919700.0
# 3  2014-09-20  408.903992  36863600.0
# 4  2014-09-21  398.821014  26580100.0

# %%
df_tesla.isna().sum()
# Out:
# MONTH              0
# TSLA_WEB_SEARCH    0
# TSLA_USD_CLOSE     0
# dtype: int64

# %%
df_unemployment.isna().sum()
# Out:
# MONTH                     0
# UE_BENEFITS_WEB_SEARCH    0
# UNRATE                    0
# dtype: int64

# %%
df_Bitcoin.isna().sum()
# Out:
# MONTH              0
# BTC_NEWS_SEARCH    0
# dtype: int64

# %%
df_Daily_Bitcoin.isna().sum()
# Out:
# DATE      0
# CLOSE     1
# VOLUME    1
# dtype: int64

# %%
print(f'Missing values for Tesla?: {df_tesla.isna().values.any()}')
print(f'Missing values for U/E?: {df_unemployment.isna().values.any()}')
print(f'Missing values for BTC Search?: {df_Bitcoin.isna().values.any()}')
print(f'Missing values for Daily Bitcoin Price?: {df_Daily_Bitcoin.isna().values.any()}')
# Out:
# Missing values for Tesla?: False
# Missing values for U/E?: False
# Missing values for BTC Search?: False
# Missing values for Daily Bitcoin Price?: True

# %%
print(f'Number of missing values: {df_Daily_Bitcoin.isna().values.sum()}')
df_Daily_Bitcoin[df_Daily_Bitcoin.CLOSE.isna()]
# Out:
# Number of missing values: 2
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %%
df_Daily_Bitcoin=df_Daily_Bitcoin.dropna()
#df_Daily_Bitcoin.dropna(inplace=True)
df_Daily_Bitcoin[df_Daily_Bitcoin.CLOSE.isna()]
# Out:
# Empty DataFrame
# Columns: [DATE, CLOSE, VOLUME]
# Index: []

# %%
print(type(df_Daily_Bitcoin.DATE[0])) #check the type
# Out:
# <class 'str'>

# %%
df_tesla.MONTH = pd.to_datetime(df_tesla.MONTH)
df_Bitcoin.MONTH = pd.to_datetime(df_Bitcoin.MONTH)
df_unemployment.MONTH = pd.to_datetime(df_unemployment.MONTH)
df_Daily_Bitcoin.DATE = pd.to_datetime(df_Daily_Bitcoin.DATE)

# %%
print(type(df_Bitcoin.MONTH[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df_tesla.MONTH.head()
# Out:
# 0   2010-06-01
# 1   2010-07-01
# 2   2010-08-01
# 3   2010-09-01
# 4   2010-10-01
# Name: MONTH, dtype: datetime64[ns]

# %% [markdown]
# # **Resampling Time Series Data**
#
# M=monthly
# Y = yearly
# T=minute

# %%
df_btc_monthly = df_Daily_Bitcoin.resample('M', on='DATE').last()
print(df_btc_monthly.shape)
df_btc_monthly.head()
# Out:
# (73, 2)
#                  CLOSE      VOLUME
# DATE
# 2014-09-30  386.944000  34707300.0
# 2014-10-31  338.321014  12545400.0
# 2014-11-30  378.046997   9194440.0
# 2014-12-31  320.192993  13942900.0
# 2015-01-31  217.464005  23348200.0

# %% [markdown]
# # **Data Visualisation - Tesla Line Charts in Matplotlib**

# %%
plt.figure(figsize=(14,8), dpi=120)

# Increase the size and rotate the labels on the x-axis
plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_ylabel('TSLA Stock Price',fontsize=12, color='#E6232E') # can use a HEX code
ax2.set_ylabel('Search Trend', fontsize=12,color='skyblue') # or a named colour

# Set the minimum and maximum values on the axes
ax1.set_ylim([0, 600])
ax1.set_xlim([df_tesla.MONTH.min(), df_tesla.MONTH.max()])

# Plot the data
ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, color='#E6232E',linewidth=3)
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH, color='skyblue',linewidth=3)
plt.show()

# %% [markdown]
# # Using Locators and DateFormatters to generate Tick Marks on a Time Line

# %%
import matplotlib.dates as mdates
#create locators for ticks on the time axis
years= mdates.YearLocator()
months= mdates.MonthLocator()
years_fmt= mdates.DateFormatter('%Y')

# format the
#ticksax1.xaxis.set_major_locator(years)ax1.xaxis.set_major_formatter(years_fmt)ax1.xaxis.set_minor_locator(months)

# %% [markdown]
# # **Data Visualisation - Bitcoin: Line Style and Markers**

# %%
plt.figure(figsize=(14,8), dpi=120)

plt.title('Bitcoin News Search vs Resampled Price', fontsize=18)
plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_ylabel('BTC Price', color='#F08F2E', fontsize=14)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)

ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.set_ylim(bottom=0, top=15000)
ax1.set_xlim([df_btc_monthly .index.min(), df_btc_monthly .index.max()])

# Experiment with the linestyle and markers
ax1.plot(df_btc_monthly.index, df_btc_monthly.CLOSE,
         color='#F08F2E', linewidth=3, linestyle='--')
ax2.plot(df_btc_monthly .index, df_Bitcoin.BTC_NEWS_SEARCH,
         color='skyblue', linewidth=3, marker='o')

plt.show()

# %% [markdown]
# # **Data Visualisation - Unemployment: How to use Grids**

# %%
plt.figure(figsize=(14,8), dpi=120)

plt.title('''Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate''', fontsize=18)
plt.xticks(fontsize=14, rotation=45)
plt.yticks(fontsize=14)

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=14)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=14)

ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.set_ylim(bottom=3, top=10.5000)
ax1.set_xlim([df_unemployment.MONTH.min(), df_unemployment.MONTH.max()])

 # Show the grid lines as dark grey lines
plt.grid(color='grey', linestyle='--')


# Change the dataset used
ax1.plot(df_unemployment.MONTH, df_unemployment.UNRATE,
         color='purple', linewidth=3, linestyle='--')
ax2.plot(df_unemployment.MONTH, df_unemployment.UE_BENEFITS_WEB_SEARCH,
         color='skyblue', linewidth=3)

plt.show()

# %% [markdown]
# Calculate the 3-month or 6-month rolling average for the web searches. Plot the 6-month rolling average search data against the actual unemployment. What do you see? Which line moves first?

# %%
plt.figure(figsize=(14,8), dpi=120)
plt.title('Rolling Monthly US "Unemployment Benefits" Web Searches vs UNRATE', fontsize=18)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14, rotation=45)

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=16)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=16)

ax1.set_ylim(bottom=3, top=10.5)
ax1.set_xlim([df_unemployment.MONTH[0], df_unemployment.MONTH.max()])

# Calculate the rolling average over a 6 month window
roll_df = df_unemployment[['UE_BENEFITS_WEB_SEARCH', 'UNRATE']].rolling(window=6).mean()

ax1.plot(df_unemployment.MONTH, roll_df.UNRATE, 'purple', linewidth=3, linestyle='-.')
ax2.plot(df_unemployment.MONTH, roll_df.UE_BENEFITS_WEB_SEARCH, 'skyblue', linewidth=3)

plt.show()

# %% [markdown]
# # Data Visualisation - Unemployment: The Effect of New Data

# %%
df_ue_2020 = pd.read_csv('UE Benefits Search vs UE Rate 2004-20.csv')
df_ue_2020.MONTH = pd.to_datetime(df_ue_2020.MONTH)

# %%
plt.figure(figsize=(14,8), dpi=120)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14, rotation=45)
plt.title('Monthly US "Unemployment Benefits" Web Search vs UNRATE incl 2020', fontsize=18)

ax1 = plt.gca()
ax2 = ax1.twinx()

ax1.set_ylabel('FRED U/E Rate', color='purple', fontsize=16)
ax2.set_ylabel('Search Trend', color='skyblue', fontsize=16)

ax1.set_xlim([df_ue_2020.MONTH.min(), df_ue_2020.MONTH.max()])

ax1.plot(df_ue_2020.MONTH, df_ue_2020.UNRATE, 'purple', linewidth=3)
ax2.plot(df_ue_2020.MONTH, df_ue_2020.UE_BENEFITS_WEB_SEARCH, 'skyblue', linewidth=3)

plt.show()
