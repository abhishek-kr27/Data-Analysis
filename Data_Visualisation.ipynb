# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishek-kr27/Data-Exploration/blob/main/Data_Visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('QueryResults.csv', names=['DATE', 'TAG', 'POSTS'], header=0)
df.head()
# Out:
#                   DATE         TAG  POSTS
# 0  2008-07-01 00:00:00          c#      3
# 1  2008-08-01 00:00:00    assembly      8
# 2  2008-08-01 00:00:00  javascript    162
# 3  2008-08-01 00:00:00           c     85
# 4  2008-08-01 00:00:00      python    124

# %%
df.tail()
# Out:
#                      DATE    TAG  POSTS
# 1986  2020-07-01 00:00:00      r   5694
# 1987  2020-07-01 00:00:00     go    743
# 1988  2020-07-01 00:00:00   ruby    775
# 1989  2020-07-01 00:00:00   perl    182
# 1990  2020-07-01 00:00:00  swift   3607

# %%
df.shape
# Out:
# (1991, 3)

# %%
df.count()
# Out:
# DATE     1991
# TAG      1991
# POSTS    1991
# dtype: int64

# %%
df.isna()
# Out:
#           m  TagName  Unnamed: 2
# 0     False    False       False
# 1     False    False       False
# 2     False    False       False
# 3     False    False       False
# 4     False    False       False
# ...     ...      ...         ...
# 1986  False    False       False
# 1987  False    False       False
# 1988  False    False       False
# 1989  False    False       False
# 1990  False    False       False
#
# [1991 rows x 3 columns]

# %%
# df.columns=['DATE', 'TAG', 'POSTS']
#df.head()

# %%
df.groupby('TAG').count() # how many months of entries exist per programming language.
# Out:
#             DATE  POSTS
# TAG
# assembly     144    144
# c            144    144
# c#           145    145
# c++          144    144
# delphi       144    144
# go           129    129
# java         144    144
# javascript   144    144
# perl         144    144
# php          144    144
# python       144    144
# r            142    142
# ruby         144    144
# swift        135    135

# %%
df[['TAG','POSTS']].groupby('TAG').sum() #how many posts each programming language had since the creation
# Out:
#               POSTS
# TAG
# assembly      34852
# c            336042
# c#          1423530
# c++          684210
# delphi        46212
# go            47499
# java        1696403
# javascript  2056510
# perl          65286
# php         1361988
# python      1496210
# r            356799
# ruby         214582
# swift        273055

# %%
type(df.DATE[1])
# Out:
# str

# %%
df.DATE=pd.to_datetime(df.DATE) #convert str into timestamp
df.head()
# Out:
#         DATE         TAG  POSTS
# 0 2008-07-01          c#      3
# 1 2008-08-01    assembly      8
# 2 2008-08-01  javascript    162
# 3 2008-08-01           c     85
# 4 2008-08-01      python    124

# %%
df.DATE[1]
# Out:
# Timestamp('2008-08-01 00:00:00')

# %%
#Data Manipulation: Pivoting DataFrames
